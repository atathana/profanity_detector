# %%
import pandas as pd

from imdb import Cinemagoer

# %% [markdown]
# ### relevant fields:

# %% [markdown]
# **Keys**
# - 'imdbID',
# - 'title',
#
# **Meta Data**
# - 'original title',
# - 'rating',
# - 'director',
# - 'runtimes',
# - 'genres',
# - 'box office',
# - 'cover url',
# - 'year',
# - 'top 250 rank',
# - 'awards',
# - 'akas',
# - 'cast',
#
# **Geo**
# - 'country codes'
# - 'countries',
# - 'locations',
# - 'language codes',
#
#
# **Text**
# - 'plot',
# - 'plot outline',
# - 'critic reviews',
# - 'reviews',
# - 'quotes'

# %%
'awards'  ???

# %% [markdown]
# # Get movie Meta Data

# %%
def get_all_movie_data(movie_name):
    ia = Cinemagoer()
    movie_search = ia.search_movie(movie_name)
    movie_id = movie_search[0].movieID
    movie_data = ia.get_movie(movie_id)
    ia.update(movie_data,'quotes')
    ia.update(movie_data,'reviews')
    ia.update(movie_data,'locations')
    
    
    return movie_data

# %%
def get_meta_data(movie_name):
    # instantiate movie request
    movie_data = get_all_movie_data(movie_name)

    # preprocess directors in case of list
    directors = []
    directors_obj = movie_data['director']
    for director in directors_obj:
        directors.append(director['name'])

    # preprocess cast list only keep top 5 listed
    cast = []
    cast_obj = movie_data['cast']
    for actor in cast_obj:
        cast.append(actor['name'])

    cast = cast[:5]

    # collect all data points to dict
    movie_meta = { "imdb_id": movie_data['imdbID'],
                   "title": movie_data['title'],
                   "rating": movie_data['rating'],
                   "director": directors,
                   "runtime" : '{0} Min'.format(movie_data['runtimes'][0]),
                   "genres" : movie_data['genres'],
                   "year" : movie_data['year'],
                   "box_office" : movie_data['box office']['Cumulative Worldwide Gross'],
                   "top_250_rank" : movie_data['top 250 rank'],
                   "cast" : cast, 
                   "cover_url" : movie_data['cover url'],
                   "akas" : movie_data['akas'],
                   "countries" : movie_data['countries']
                 }
    return movie_meta

# %%
def get_movie_quotes_df(movie_name):
    #get data
    movie_data = get_all_movie_data(movie_name)
    #create quotes dict
    quotes_dict = {"imdb_id": movie_data['imdbID'],
                   "title": movie_data['title'],
                   "quotes": movie_data['quotes']}
    #create quotes df
    quotes_df = pd.DataFrame(quotes_dict)
    #turn quotes from lists to strings
    quotes_df['quotes'] = quotes_df.apply(lambda x : ", ".join(x['quotes']), axis=1)
    
    return quotes_df

# %%
def get_movie_reviews_df(movie_name):
    #get data
    movie_data = get_all_movie_data(movie_name)
    
    #create quotes df
    reviews_df = pd.DataFrame(movie_data['reviews'])
    reviews_df['imdb_id'] = movie_data['imdbID']
    reviews_df['title'] = movie_data['title']
      
    return reviews_df

# %%
def get_movie_locations_df(movie_name):
    #get data
    movie_data = get_all_movie_data(movie_name)
    
    #create quotes df
    locations_df = pd.DataFrame(movie_data['locations'])
    locations_df['imdb_id'] = movie_data['imdbID']
    locations_df['title'] = movie_data['title']
      
    return locations_df

# %%
get_meta_data('matrix')
# Out:
# {'akas': ['Matrix (Japan, English title)',
#   'Matrix (France)',
#   'Matrix (Germany)',
#   'Matrix (Spain)',
#   '黑客帝国 (China, Mandarin title)'],
#  'box_office': '$463,517,383',
#  'cast': ['Keanu Reeves',
#   'Laurence Fishburne',
#   'Carrie-Anne Moss',
#   'Hugo Weaving',
#   'Gloria Foster'],
#  'countries': ['United States', 'Australia'],
#  'cover_url': 'https://m.media-amazon.com/images/M/MV5BNzQzOTk3OTAtNDQ0Zi00ZTVkLWI0MTEtMDllZjNkYzNjNTc4L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX101_CR0,0,101,150_.jpg',
#  'director': ['Lana Wachowski', 'Lilly Wachowski'],
#  'genres': ['Action', 'Sci-Fi'],
#  'imdb_id': '0133093',
#  'rating': 8.7,
#  'runtime': '136 Min',
#  'title': 'The Matrix',
#  'top_250_rank': 16,
#  'year': 1999}

# %%
get_movie_quotes_df('matrix')
# Out:
#      imdb_id                                             quotes       title
# 0    0133093  Morpheus: This is your last chance. After this...  The Matrix
# 1    0133093  Agent Smith: I'd like to share a revelation th...  The Matrix
# 2    0133093  Spoon boy: Do not try and bend the spoon. That...  The Matrix
# 3    0133093  Neo: What are you trying to tell me? That I ca...  The Matrix
# 4    0133093  Morpheus: Neo, sooner or later you're going to...  The Matrix
# ..       ...                                                ...         ...
# 110  0133093  Agent Smith: Dammit., Agent Brown: The trace w...  The Matrix
# 111  0133093  Mouse: [to Neo] So I understand that, uh, you'...  The Matrix
# 112  0133093  Morpheus: What are you waiting for? You're fas...  The Matrix
# 113  0133093  [Neo has just been revived after escaping from...  The Matrix
# 114  0133093  Morpheus: [explaining 'agents'] Sentient progr...  The Matrix
#
# [115 rows x 3 columns]

# %%
get_movie_reviews_df('matrix')
# Out:
#         author                                            content  \
# 0    ur2467618  There are currently almost 2800 reviews on IMD...
# 1   ur20552756  'The Matrix' may not be one of the very greate...
# 2    ur0482513  What is THE MATRIX? Well, let me tell you: it'...
# 3    ur2898520  The Wachowski brothers have created one of the...
# 4    ur0278527  This is one of those movies that "everyone" ha...
# 5   ur61197531  and this is all. because each explanation soun...
# 6    ur3914439  15 years ago, back in the 20th century, the fi...
# 7    ur4569900  What made The Matrix special was the groundbre...
# 8    ur1002035  Neo is a computer programmer by day and a inte...
# 9    ur5876717  The Wachowsky Brothers took many elements, fro...
# 10   ur2707735  I saw this movie when it first came out, and c...
# 11   ur4888011  When "The Matrix" first came out, it looked li...
# 12   ur4248714  This is considered by many to be a milestone o...
# 13   ur4445210  Special-effects were the drawing card when thi...
# 14  ur13977076  Like many people I was fairly awestruck by the...
# 15   ur3270789  Overwhelming and spectacular first part from a...
# 16  ur22654354  I sat down here in 2021 to re-watch the 1999 a...
# 17   ur0945066  With The Matrix having already received 3294 c...
# 18   ur0989035  Glorified martial arts movie masquerading as a...
# 19   ur0438066  December 2019 update. My wife and I just watch...
# 20   ur1219578  Launched in 1999 and one of the most successfu...
# 21   ur0453068  Andy and Larry Wachowski's The Matrix is an un...
# 22  ur15896852  Insomniac computer hacker Keanu Reeves (as Tho...
# 23   ur0449021  A computer cowboy rides into a new realm of re...
# 24   ur5291991  The Matrix is a science fiction action film wr...
#
#                  date  helpful  not_helpful  rating       title  imdb_id
# 0    22 February 2018       39          178     7.0  The Matrix  0133093
# 1    20 February 2017       38           10     9.0  The Matrix  0133093
# 2      26 August 2016       14            7     9.0  The Matrix  0133093
# 3     9 November 2013       13            6     9.0  The Matrix  0133093
# 4      20 August 2019       17            6     9.0  The Matrix  0133093
# 5      8 January 2017       28            5     NaN  The Matrix  0133093
# 6    29 November 2014       17           90     6.0  The Matrix  0133093
# 7       28 March 2016       14           21     7.0  The Matrix  0133093
# 8        20 June 2002       13           13     NaN  The Matrix  0133093
# 9        21 July 2009        3            5     9.0  The Matrix  0133093
# 10  25 September 2011        3            3     9.0  The Matrix  0133093
# 11    21 October 2005        7           16     8.0  The Matrix  0133093
# 12       23 June 2005       11           28    10.0  The Matrix  0133093
# 13    18 October 2006       19           21     8.0  The Matrix  0133093
# 14   28 February 2012        7            5    10.0  The Matrix  0133093
# 15   20 February 2012       11            7     9.0  The Matrix  0133093
# 16   22 December 2021        4           14     6.0  The Matrix  0133093
# 17   14 November 2009        8            6    10.0  The Matrix  0133093
# 18       4 March 2009        8           35     4.0  The Matrix  0133093
# 19  30 September 1999       13           13     NaN  The Matrix  0133093
# 20  18 September 2003       11           37     5.0  The Matrix  0133093
# 21     5 October 2000       24           16    10.0  The Matrix  0133093
# 22     1 January 2009        5            3     9.0  The Matrix  0133093
# 23       8 April 2000        5            8     7.0  The Matrix  0133093
# 24   26 February 2012        6            2    10.0  The Matrix  0133093

# %%
get_movie_locations_df('matrix')
# Out:
#                                                     0  imdb_id       title
# 0   Nashville, Tennessee, USA::(exterior scenes: s...  0133093  The Matrix
# 1                  Sydney, New South Wales, Australia  0133093  The Matrix
# 2   Redfern, Sydney, New South Wales, Australia::(...  0133093  The Matrix
# 3   San Francisco, California, USA::(exterior scen...  0133093  The Matrix
# 4   Sydney Central Business District, Sydney, New ...  0133093  The Matrix
# 5   Colonial State Bank Centre, Martin Place, Sydn...  0133093  The Matrix
# 6   Westin Hotel, Martin Place, Sydney, New South ...  0133093  The Matrix
# 7   Fox Studios, Moore Park, Sydney, New South Wal...  0133093  The Matrix
# 8   Forty One Restaurant, Chifley Tower, Sydney, N...  0133093  The Matrix
# 9   AON Tower, Kent Street, Sydney, New South Wale...  0133093  The Matrix
# 10  BT Tower, Market Street, Sydney, New South Wal...  0133093  The Matrix
# 11  Corner of Pitt, O'Connell and Hunter Streets, ...  0133093  The Matrix
# 12  Hickson Road, Millers Point, Sydney, New South...  0133093  The Matrix
# 13  Rozelle, Sydney, New South Wales, Australia::(...  0133093  The Matrix
# 14  Waterloo, Sydney, New South Wales, Australia::...  0133093  The Matrix
# 15  White Bay Studios, Balmain, Sydney, New South ...  0133093  The Matrix
# 16  Museum Underground Station, Hyde Park, Sydney,...  0133093  The Matrix
# 17  Martin Place Fountain, Martin Place, Sydney, N...  0133093  The Matrix
# 18  Pittwater, Broken Bay, New South Wales, Australia  0133093  The Matrix
# 19    Surry Hills, Sydney, New South Wales, Australia  0133093  The Matrix
# 20  Allianz Building, Market Street, Sydney, New S...  0133093  The Matrix
# 21    Chippendale, Sydney, New South Wales, Australia  0133093  The Matrix
